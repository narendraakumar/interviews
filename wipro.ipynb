# %%
var = "str"

def palindrome_validate(s):
    return list(s)==list(s)[::-1]

@decorator
def palindrome_validate2(s):
    p = False
    for i in range(int((len(s)/2))+1):
        l_s = s[i]
        r_s = s[len(s)-1-i]
        if l_s == r_s:
            p = True
        else:
            p = False
            return p
    return p

print(palindrome_validate("bababa"))
print(palindrome_validate2("bababa"))
# Out:
# False
# False

# %%
class A:
    pass
class B:
    pass

class C(A):
    def __init__(*args,**kwargs):
        super(A).__init__(*args,**kwargs)
        
C("")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 10>()
#       7     def __init__(*args,**kwargs):
#       8         super(A)(*args,**kwargs)
# ---> 10 C("")
#
# Input In [13], in C.__init__(*args, **kwargs)
#       7 def __init__(*args,**kwargs):
# ----> 8     super(A)(*args,**kwargs)
#
# TypeError: 'super' object is not callable

# %%
import math
def prime_no(n):
    if n in [1,2]:
        return f"{n} this is prime no."
    p = True
    n_s = int(math.sqrt(n))+1
    for i in range(2,n_s):
        if n%i==0:
            p = False
            return f"{n} not prime no."
    
    return f"{n} this is prime no."
for i in range(1, 100):
    print(prime_no(i))
# Out:
# 1 this is prime no.
# 2 this is prime no.
# 3 this is prime no.
# 4 not prime no.
# 5 this is prime no.
# 6 not prime no.
# 7 this is prime no.
# 8 not prime no.
# 9 not prime no.
# 10 not prime no.
# 11 this is prime no.
# 12 not prime no.
# 13 this is prime no.
# 14 not prime no.
# 15 not prime no.
# 16 not prime no.
# 17 this is prime no.
# 18 not prime no.
# 19 this is prime no.
# 20 not prime no.
# 21 not prime no.
# 22 not prime no.
# 23 this is prime no.
# 24 not prime no.
# 25 not prime no.
# 26 not prime no.
# 27 not prime no.
# 28 not prime no.
# 29 this is prime no.
# 30 not prime no.
# 31 this is prime no.
# 32 not prime no.
# 33 not prime no.
# 34 not prime no.
# 35 not prime no.
# 36 not prime no.
# 37 this is prime no.
# 38 not prime no.
# 39 not prime no.
# 40 not prime no.
# 41 this is prime no.
# 42 not prime no.
# 43 this is prime no.
# 44 not prime no.
# 45 not prime no.
# 46 not prime no.
# 47 this is prime no.
# 48 not prime no.
# 49 not prime no.
# ...
